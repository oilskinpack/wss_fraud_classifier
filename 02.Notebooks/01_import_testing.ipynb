# %%
from Utils.io import get_union_raw_data
from prep.preprocessing_config import sk_names_map_dict
from Utils.string_utils import extract_degrees
from Utils.numeric_utils import convert_to_double
from Data_prep.prep_transformers import SectionCheck
from Data_prep.data_preparer import build_preparer

data = get_union_raw_data()
preparing_pipeline = build_preparer()
prepared_data = preparing_pipeline.fit_transform(data)
prepared_data
# Out:
#        Секция_ОК  Секция_Паркинг  Этаж_ОК Этаж_Отметка  ЧастьСистемы_ОК  \
# 0            1.0             0.0      1.0    Выше нуля              1.0
# 1            1.0             0.0      1.0    Выше нуля              1.0
# 2            1.0             0.0      1.0    Ниже нуля              1.0
# 3            1.0             0.0      1.0    Ниже нуля              1.0
# 4            1.0             0.0      1.0    Ниже нуля              1.0
# ...          ...             ...      ...          ...              ...
# 24176        1.0             0.0      1.0    Выше нуля              1.0
# 24177        1.0             0.0      1.0    Выше нуля              1.0
# 24178        1.0             0.0      1.0    Выше нуля              1.0
# 24179        1.0             0.0      1.0    Выше нуля              1.0
# 24180        1.0             0.0      1.0    Выше нуля              1.0
#
#                 ЧастьСистемы_Тип  Толщина стенки  Итого_ОК  \
# ...
