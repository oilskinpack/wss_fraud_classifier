# %%
from Utils.io import get_union_raw_data
from Data_prep.data_preparer import build_preparer
from Utils.plots_utils import show_corr_features_with
import seaborn as sns

data = get_union_raw_data()
preparing_pipeline = build_preparer()
df = preparing_pipeline.fit_transform(data)
df['Ошибка'] = data['Ошибка']

# %%
print(df.isnull().sum())

#Нулевых значений нет
# Out:
# Секция_ОК             0
# Секция_Паркинг        0
# Этаж_ОК               0
# Этаж_Отметка          0
# ЧастьСистемы_ОК       0
# ЧастьСистемы_Тип      0
# Толщина стенки        0
# Итого_ОК              0
# Тип_СК_Регл           0
# Тип_Регл              0
# Размер_Первый         0
# Размер_Второй         0
# Размер_Третий         0
# Размер_Кол-во         0
# Вид_Сортамент         0
# Вид_Угол              0
# Вид_Угол_Кратность    0
# СК_Симв_ОК            0
# Ошибка                0
# dtype: int64

# %%
#Сколько ошибок
sns.countplot(data=df,x='Ошибка',palette='viridis')
# Out:
# D:\Temp\TEMP\ipykernel_22940\3205040165.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='Ошибка',palette='viridis')
# <Axes: xlabel='Ошибка', ylabel='count'>

# %%
df['Этаж_ОК'].value_counts()

#Представлен прилично
# Out:
# Этаж_ОК
# 1.0    21670
# 0.0     2511
# Name: count, dtype: int64

# %%
def show_df_with_value(param,value):
    indexes = df[df[param] == value].index
    return data.iloc[indexes]
res = show_df_with_value('Этаж_ОК',0)
res
# Out:
#       Единица приемки (ЕП), Секция  \
# 5840                    Адм.корпус
# 5841                    Адм.корпус
# 5842                    Адм.корпус
# 5843                    Адм.корпус
# 5844                    Адм.корпус
# ...                            ...
# 22217                     Секция 2
# 22266                     Секция 2
# 22306                     Секция 2
# 22785                     Секция 3
# 22886                     Секция 3
#
#                               Единица приемки (ЕП), Этаж  \
# 5840                            Магистраль 1В1, Этаж -01
# 5841                            Магистраль 1В1, Этаж -01
# 5842                            Магистраль 1Т3, Этаж -01
# 5843                            Магистраль 1Т3, Этаж -01
# 5844                            Магистраль 1Т3, Этаж -01
# ...                                                  ...
# 22217  Стояк В1.1, Этаж -01 (отм -3,800) - Этаж 09 (о...
# 22266  Стояк Т3.1, Этаж -01 (отм -3,800) - Этаж 09 (о...
# ...

# %%
res = show_df_with_value('Секция_ОК',0)
res


#Всего 76 элементов. Этого маловато
# Out:
#      Единица приемки (ЕП), Секция            Единица приемки (ЕП), Этаж  \
# 3480                            ё  Разводка В1.1, Этаж 03 (отм. +7,200)
# 5840                   Адм.корпус              Магистраль 1В1, Этаж -01
# 5841                   Адм.корпус              Магистраль 1В1, Этаж -01
# 5842                   Адм.корпус              Магистраль 1Т3, Этаж -01
# 5843                   Адм.корпус              Магистраль 1Т3, Этаж -01
# ...                           ...                                   ...
# 5910                   Адм.корпус      Стояк 1В1, Этаж 01 (отм. +0,000)
# 5911                   Адм.корпус      Стояк 1В1, Этаж 01 (отм. +0,000)
# 5912                   Адм.корпус                   Стояк 1Т3, Этаж -01
# 5913                   Адм.корпус      Стояк 1Т3, Этаж 01 (отм. +0,000)
# 5914                   Адм.корпус      Стояк 1Т3, Этаж 01 (отм. +0,000)
#
#                                       Тип СК  \
# 3480  Соединительная деталь полимерной трубы
# ...

# %%
res = show_df_with_value('Этаж_Отметка','Неверный формат')
res

#Этаж_Отметка == Неверный формат - Представлены хорошо
# Out:
#       Единица приемки (ЕП), Секция  \
# 5840                    Адм.корпус
# 5841                    Адм.корпус
# 5842                    Адм.корпус
# 5843                    Адм.корпус
# 5844                    Адм.корпус
# ...                            ...
# 22217                     Секция 2
# 22266                     Секция 2
# 22306                     Секция 2
# 22785                     Секция 3
# 22886                     Секция 3
#
#                               Единица приемки (ЕП), Этаж  \
# 5840                            Магистраль 1В1, Этаж -01
# 5841                            Магистраль 1В1, Этаж -01
# 5842                            Магистраль 1Т3, Этаж -01
# 5843                            Магистраль 1Т3, Этаж -01
# 5844                            Магистраль 1Т3, Этаж -01
# ...                                                  ...
# 22217  Стояк В1.1, Этаж -01 (отм -3,800) - Этаж 09 (о...
# 22266  Стояк Т3.1, Этаж -01 (отм -3,800) - Этаж 09 (о...
# ...

# %%
res = show_df_with_value('ЧастьСистемы_ОК',0)
res

#Здесь 1561 элементов и в целом похоже этого достаточно
# Out:
#       Единица приемки (ЕП), Секция  \
# 39                        Секция 1
# 40                        Секция 1
# 41                        Секция 1
# 46                        Секция 1
# 149                       Секция 1
# ...                            ...
# 24163                     Секция 8
# 24164                     Секция 8
# 24165                     Секция 8
# 24166                     Секция 8
# 24167                     Секция 8
#
#                               Единица приемки (ЕП), Этаж  \
# 39                 Магистраль Т3, Этаж -01 (отм. -3,800)
# 40                 Магистраль Т3, Этаж -01 (отм. -3,800)
# 41                 Магистраль Т3, Этаж -01 (отм. -3,800)
# 46                 Магистраль Т4, Этаж -01 (отм. -3,800)
# 149                 Магистраль Т3, Этаж 01 (отм. +0,600)
# ...                                                  ...
# 24163                   Стояк Т3, Этаж -01 (отм. -3,800)
# 24164                   Стояк Т3, Этаж -01 (отм. -3,800)
# ...

# %%
res = df[['Толщина стенки','Тип_СК_Регл']].value_counts().reset_index().sort_values('Толщина стенки')
res

#Можно заключить, что как и ожидалось, толщина стенки есть только у:
#   - метал труб и сдт
#   - изоляции
# Out:
#     Толщина стенки                                Тип_СК_Регл  count
# 0              0.0     Полимерная соединительная деталь трубы   8031
# 1              0.0                           Труба полимерная   4280
# 2              0.0                         Префаб-изделие ВИС   3633
# 3              0.0                              Арматура труб   2027
# 6              0.0                               Оборудование    976
# 9              0.0  Металлическая соединительная деталь трубы    402
# 8              1.0                         Изоляция трубчатая    539
# 13             1.0  Металлическая соединительная деталь трубы    150
# 15             1.5                        Труба металлическая     46
# 17             1.8                        Труба металлическая     42
# 20             1.8  Металлическая соединительная деталь трубы     38
# 14             2.0                        Труба металлическая     67
# 21             2.0  Металлическая соединительная деталь трубы     26
# ...

# %%
res = show_df_with_value('Итого_ОК',0)
res

#3 элемента, крайне мало. Нужно расшивать
# Out:
#       Единица приемки (ЕП), Секция             Единица приемки (ЕП), Этаж  \
# 4987                      Секция 6   Разводка В1.1, Этаж 03 (отм. +7,650)
# 18023                     Секция 6   Разводка В1.1, Этаж 03 (отм. +7,650)
# 22711                     Секция 3  Разводка Т3.1, Этаж 13 (отм. +37,170)
#
#                    Тип СК                                                 СК  \
# 4987   Изоляция трубчатая  Изоляция трубчатая Водоснабжение, Трубки Energ...
# 18023  Изоляция трубчатая  Изоляция трубчатая Водоснабжение, Трубки Energ...
# 22711  Изоляция трубчатая  Изоляция трубчатая Водоснабжение, Вспененный п...
#
#        Ошибка  Итого   Параметр  Количество, шт  Площадь, м2  Объем, м3  \
# 4987        1    0.0  Длина, мм               2          0.0        0.0
# 18023       1    0.0  Длина, мм               2          0.0        0.0
# 22711       1    0.0  Длина, мм               1          0.0        0.0
#
# ...

# %%
res = show_df_with_value('Тип_Регл',"Не определено")
res


#121 строчки на нерегламентированный тип - тоже маловато
# Out:
#       Единица приемки (ЕП), Секция  \
# 3500                     Секция 10
# 3502                     Секция 10
# 3737                      Секция 1
# 3739                      Секция 1
# 3946                      Секция 2
# ...                            ...
# 18204                     Секция 7
# 18438                     Секция 8
# 18440                     Секция 8
# 18656                     Секция 9
# 18658                     Секция 9
#
#                               Единица приемки (ЕП), Этаж        Тип СК  \
# 3500    Индивидуальный узел учета, Этаж 01 (отм. -0,150)  Оборудование
# 3502   Индивидуальный узел учета, Этаж -01 (отм. -3,820)  Оборудование
# 3737    Индивидуальный узел учета, Этаж 01 (отм. -0,150)  Оборудование
# 3739   Индивидуальный узел учета, Этаж -01 (отм. -3,820)  Оборудование
# 3946    Индивидуальный узел учета, Этаж 01 (отм. -0,150)  Оборудование
# ...                                                  ...           ...
# ...

# %%
res = df[['Размер_Первый','Тип_СК_Регл']].value_counts().reset_index().sort_values('Размер_Первый')
res



#Размеры корректные
# Out:
#      Размер_Первый                                Тип_СК_Регл  count
# 0              0.0                         Префаб-изделие ВИС   3633
# 7              0.0     Полимерная соединительная деталь трубы    972
# 6              0.0                               Оборудование    976
# 18             0.0                         Изоляция трубчатая    362
# 20             0.0                           Труба полимерная    343
# ..             ...                                        ...    ...
# 107          219.0                        Труба металлическая      1
# 84           225.0                           Труба полимерная      3
# 83           225.0     Полимерная соединительная деталь трубы      3
# 48           250.0  Металлическая соединительная деталь трубы     19
# 68           250.0                              Арматура труб      5
#
# [109 rows x 3 columns]

# %%
res = show_df_with_value('Размер_Кол-во',2).index
res2 = df.loc[res]
res2


#Ошибки с двойным и более размером представлены порядка 500 - лучше бы расшить
# Out:
#        Секция_ОК  Секция_Паркинг  Этаж_ОК Этаж_Отметка  ЧастьСистемы_ОК  \
# 77           1.0             0.0      1.0    Ниже нуля              1.0
# 78           1.0             0.0      1.0    Ниже нуля              1.0
# 79           1.0             0.0      1.0    Ниже нуля              1.0
# 108          1.0             0.0      1.0    Ниже нуля              1.0
# 118          1.0             0.0      1.0    Ниже нуля              1.0
# ...          ...             ...      ...          ...              ...
# 24160        1.0             0.0      1.0    Выше нуля              1.0
# 24163        1.0             0.0      1.0    Ниже нуля              0.0
# 24169        1.0             0.0      1.0    Ниже нуля              1.0
# 24170        1.0             0.0      1.0    Ниже нуля              1.0
# 24179        1.0             0.0      1.0    Выше нуля              1.0
#
#       ЧастьСистемы_Тип  Толщина стенки  Итого_ОК  \
# 77          Магистраль             0.0       1.0
# ...

# %%
res = show_df_with_value('СК_Симв_ОК',0)
res


#1770 гуд
# Out:
#       Единица приемки (ЕП), Секция           Единица приемки (ЕП), Этаж  \
# 3481                      Секция 4  Насосная ХП, Этаж -01 (отм. -3,800)
# 3730                     Секция 10                Этаж 02 (отм. +4,050)
# 3731                     Секция 10                Этаж 03 (отм. +7,650)
# 3732                     Секция 10               Этаж 04 (отм. +10,650)
# 3733                     Секция 10               Этаж 05 (отм. +13,650)
# ...                            ...                                  ...
# 18871                     Секция 9                Этаж 02 (отм. +4,050)
# 18872                     Секция 9                Этаж 03 (отм. +7,650)
# 18873                     Секция 9               Этаж 05 (отм. +13,650)
# 18874                     Секция 9               Этаж 06 (отм. +16,650)
# 18875                     Секция 9               Этаж 07 (отм. +19,650)
#
#                                           Тип СК  \
# 3481   Соединительная деталь трубы металлической
# ...

# %%
show_corr_features_with('Ошибка',df)

# %%
show_corr_features_with('Ошибка',df,False)
